# %% [markdown]
# ## Instrucciones para el Laboratorio
#
# Para cada ejercicio del laboratorio, se requiere seguir estos pasos:
#
# 1. **Desarrollo del Pseudocódigo**: Antes de comenzar a programar, elabora un pseudocódigo para cada solución. El pseudocódigo debe detallar la lógica y los pasos necesarios para resolver el problema de manera clara y estructurada. Esto te ayudará a comprender mejor la solución antes de codificarla.
#
# 2. **Implementación del Programa**: Una vez que tengas el pseudocódigo listo y revisado, procede a programar la solución en Python. Asegúrate de que tu código siga la lógica que has definido en el pseudocódigo y cumpla con los requisitos especificados en cada ejercicio.
#
# Recuerda que una buena planificación a través del pseudocódigo facilitará el proceso de programación y te permitirá identificar posibles errores antes de implementar el código.

# %% [markdown]
# ## Ejercicio: Transformación de Palabras
#
# Dada la lista de palabras:

# %%
words = ['play', 'filling', 'bar', 'theatre', 'easygoing', 'date', 'lead', 'that', 'story',  'island']

# %% [markdown]
# 1. **Imprimir Letras Mayúsculas**: Escribe un programa que imprima todas las letras de cada palabra en la lista en mayúsculas, separando cada letra por una coma.

# %%
# tu pseudocodigo aquí
# dada una lista se recorre cada palabra
# para cada palabra, se recorre con un bucle cada letra y se pasa a mayuscula y se gurada en una nueva lista
# se imprimen las letras la la lista separadas por coma

# %%
# tu codigo aquí

for palabra in words:
    letras = [letra.upper() for letra in palabra]
    print(", ".join(letras))

# %% [markdown]
# 2. **Crear una Nueva Lista**: Genera una nueva lista que contenga solo las palabras que tengan 5 o más letras. Luego, imprime esta nueva lista.

# %%
# tu pseudocodigo aquí
# dada una lista, se recorre con un bucle 
# para cada palabra se comprueba que tenga más de 5 letras
# en tal caso se gurada en una nueva lista

# %%
# tu codigo aquí
nueva_lista = []
for palabra in words:
    if len(palabra) >= 5: 
        nueva_lista += [palabra]

#otra manera
nueva_lista = [palabra for palabra in words if len(palabra) >= 5]

print(nueva_lista)

# %% [markdown]
# 3. **Encontrar Palabras que Comienzan con 't'**: Imprime la primera palabra en la lista que comience con la letra 't'. Si no hay ninguna, imprime un mensaje indicando que no se encontró ninguna palabra que empiece con 't'.

# %%
# tu pseudocodigo aquí
# dada una lista, se recorre con un bucle 
# para cada palabra se comprueba que empiece por t
# se imprime y se incrementa el contador
# si el contador es 0, se imprime que no hay palabras que empiecen por t

# %%
# tu codigo aquí
count = 0
for palabra in words:
    if palabra.startswith("t"): 
        count+=1
        print(palabra)

if count == 0: print("No hay palabras que empiecen por t")

# %% [markdown]
# 4. **Contar las Vocales**: Escribe un programa que cuente y imprima el número total de vocales en todas las palabras de la lista.

# %%
# tu pseudocodigo aquí
# dada una lista, se recorre con un bucle 
# para cada palabra se recorre en bucle las letras
# para cada letra se comprueba si es vocal
# si es vocal se incrementa el contador
# se imprime el contador

# %%
# tu codigo aquí
vocales = "aeiouAEIOU"
total_vocales = 0

for palabra in words:
    for letra in palabra:
        if letra in vocales:
            total_vocales += 1

print("El número total de vocales es:", total_vocales)

# %% [markdown]
# 5. **Palabras que Contienen la Letra 'a'**: Crea una nueva lista que contenga solo las palabras que tengan la letra 'a'. Imprime esta nueva lista.

# %%
# tu pseudocodigo aquí
# imprime una nueva lista de palabras filtradas en un bucle por las que contienen "a"

# %%
# tu codigo aquí

print( [palabra for palabra in words if palabra.__contains__("a")] )

# %% [markdown]
# 6. **Palabras en Orden Inverso**: Imprime la lista de palabras en orden inverso, de la última a la primera.

# %%
# tu pseudocodigo aquí
# Imprime la lista de palabras en orden inverso usando notación python

# %%
# tu codigo aquí
print(words[::-1])

# %% [markdown]
# ## Numeros Primos

# %% [markdown]
# 1. **Lista de Números Primos**:
#    Crea una lista que contenga los números primos entre 1 y 20. Imprime la lista.

# %%
# tu pseudocodigo aquí
# Para cada numero de una lista ascendente y una lista de antecesores primos vacia
# comprueba si el numero es divisible por los antecesores primos
# si no es divisible por los antecesores primos, lo añade a la lista de primos
# imprime la lista de antecesores primos del numero 20

# %%
# tu codigo aquí

def is_prime(num, primes):
    for prime in primes[1:]:
        if(num % prime == 0): 
            return False
    return True

def get_primes(lim, primes):
    for num in range(2, lim+1):
        if (is_prime(num, primes)):
            primes.append(num)
    return primes

print(get_primes(20, []))

# %% [markdown]
# 2. **Contar Números Primos**:
#    Escribe un programa que cuente cuántos números primos hay entre 1 y 30. Imprime el total.

# %%
# tu pseudocodigo aquí
# Para cada numero de una lista ascendente y una lista de antecesores primos vacia
# comprueba si el numero es devisible por los antecesores primos
# si no es divisible por los antecesores primos, lo añade a la lista de primos
# imprime la longitud de la lista de antecesores primos del numero 30

# %%
# tu codigo aquí

print(len(get_primes(30, [])))

# %% [markdown]
# 3. **Suma de Números Primos**:
#    Crea un programa que calcule la suma de los números primos menores de 50 y la imprima.

# %%
# tu pseudocodigo aquí
# Para cada numero de una lista ascendente y una lista de antecesores primos vacia
# comprueba si el numero es divisible por los antecesores primos
# si no es divisible por los antecesores primos, lo añade a la lista de primos
# imprime la suma de la lista de antecesores primos del numero 50

# %%
# tu codigo aquí
print(sum(get_primes(50, [])))

# %% [markdown]
# 4. **Verificar si un Número es Primo**:
#    Escribe un programa que pida al usuario un número y que determine si es primo. Imprime un mensaje indicando si el número es primo o no.

# %%
# tu pseudocodigo aquí
# Para cada numero de una lista ascendente y una lista de antecesores primos vacia
# comprueba si el numero es divisible por los antecesores primos
# si no es divisible por los antecesores primos, lo añade a la lista de primos
# Pide un número al usuario 
# imprime si el input está en la lista de antecesores primos del input

# %%
# tu codigo aquí
num = int(input())
primes = get_primes(num, [])
print(f"¿Es {num} un número primo?: {primes.__contains__(num)}")

# %% [markdown]
# 5. **Primos Menores a un Número**:
#    Crea un programa que pida al usuario un número y que imprima todos los números primos menores que ese número.

# %%
# tu pseudocodigo aquí
# Para cada numero de una lista ascendente y una lista de antecesores primos vacia
# comprueba si el numero es divisible por los antecesores primos
# si no es divisible por los antecesores primos, lo añade a la lista de primos
# Pide un número al usuario 
# imprime la lista de antecesores primos del input

# %%
# tu codigo aquí
num = int(input())
print(get_primes(num-1, []))

# %% [markdown]
# 6. **Lista de Primos en un Rango**:
#    Crea un programa que genere e imprima los números primos entre 10 y 50.

# %%
# tu pseudocodigo aquí
# Para cada numero de una lista ascendente y una lista de antecesores primos vacia
# comprueba si el numero es divisible por los antecesores primos
# si no es divisible por los antecesores primos, lo añade a la lista de primos
# obtiene la lista de antecesores primos del limita superior del rango
# Elimina los antecesores inferiores al limite inferior del rango
# Imprime la lista de antecesores primos comprendidos en el rango

# %%
# tu codigo aquí

primes = get_primes(50, [])
primes = [prime for prime in primes if prime >= 10]
print(primes)

# %% [markdown]
# ## People
#
# Dada la siguiente lista de personas:

# %%
people = [
    {
        "name": "Juan",
        "age": 34,
        "n_kids": 2,
        "city": "Madrid"
    },
    {
        "name": "Pepe",
        "age": 27,
        "n_kids": 0,
        "city": "Barcelona"
    },
    {
        "name": "Sonia",
        "age": 41,
        "n_kids": 1,
        "city": "Valencia"
    },
    {
        "name": "Lucía",
        "age": 22,
        "n_kids": 2,
        "city": "Sevilla"
    },
    {
        "name": "Leo",
        "age": 55,
        "n_kids": 5,
        "city": "Bilbao"
    },
    {
        "name": "Marta",
        "age": 30,
        "n_kids": 3,
        "city": "Zaragoza"
    },
    {
        "name": "Carlos",
        "age": 45,
        "n_kids": 0,
        "city": "Granada"
    }
]

# %% [markdown]
# 1. **Contar Personas**:
#    Escribe un programa que cuente cuántas personas hay en la lista `people`. Imprime el total.

# %%
# tu pseudocodigo aquí
# Imprime la longitud de la lista usando funciones de python

# %%
# tu codigo aquí
print("total de personas: ", len(people))

# %% [markdown]
# 2. **Contar Personas con Hijos**:
#    Crea un programa que cuente cuántas personas tienen al menos un hijo. Imprime el número de estas personas.

# %%
# tu pseudocodigo aquí
# Filtra la lista accediendo por key al dato dentro de un bucle
# imprime el total de datos filtrados

# %%
# tu codigo aquí
print("total de personas con hijos: ", len([person for person in people if person["n_kids"] > 0]))

# %% [markdown]
# 3. **Contar Hijos Totales**:
#    Escribe un programa que calcule cuántos hijos hay en total entre todas las personas de la lista. Imprime el total.

# %%
# tu pseudocodigo aquí
# Accede por key al dato dentro de un bucle
# imprime el sumatorio de los valores de n_kids

# %%
# tu codigo aquí
print("total de hijos: ", sum([person["n_kids"] for person in people]))

# %% [markdown]
# 4. **Promedio de Edad**:
#    Calcula y muestra la edad promedio de las personas en la lista.

# %%
# tu pseudocodigo aquí
# Accede por key al dato dentro de un bucle
# Calcula e imprime la media del campo age

# %%
# tu codigo aquí
print("media de edad: ", sum([person["age"] for person in people]) / len(people))

# %% [markdown]
# 5. **Lista de Personas que Terminan en 'a'**:
#    Genera una lista con los nombres de las personas cuyo nombre termina en "a". Imprime esta lista.

# %%
# tu pseudocodigo aquí
# Filtra la lista accediendo por key al dato dentro de un bucle
# imprime la lista de campos name

# %%
# tu codigo aquí
print("Personas con nombre terminado en a: ", [person["name"] for person in people if person["name"].endswith("a") ])

# %% [markdown]
# 6. **Actualizar Información por Año**:
#    En un año, las personas cuyos nombres terminan en "a" tendrán un niño extra. Crea una nueva lista de diccionarios con la información actualizada de las personas (edad incrementada en 1 y `n_kids` aumentado en 1 para las que terminan en "a"). Imprime esta nueva lista.

# %%
# tu pseudocodigo aquí
# tu pseudocodigo aquí
# Filtra la lista accediendo por key al dato dentro de un bucle
# imprime la lista de nuevos diccionarios con datos actualizados

# %%
# tu codigo aquí

nueva_lista = [
    {
        "name": person["name"],
        "age": person["age"] + 1,
        "n_kids": person["n_kids"] + (1 if person["name"].endswith("a") else 0),
        "city": person["city"],
    }
    for person in people]

print(nueva_lista)
